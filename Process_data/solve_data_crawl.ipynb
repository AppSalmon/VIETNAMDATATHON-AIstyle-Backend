# %%
import pandas as pd
import numpy as np
import json 
import re

# %%
path = 'data_adidas_2.json'
df = pd.read_json(path)
df.sample(3)
# Out:
#     availability  avg_rating   brand          color currency  \
# 624      InStock         NaN  adidas   Wonder Beige      USA
# 688      InStock         NaN  adidas  Crew Navy S21      USA
# 146      InStock         NaN  adidas  Black / Black      USA
#
#                                            description  \
# 624  A FLEECY SOFT LOOSE-FIT PULLOVER MADE IN PART ...
# 688  CLASSIC TRAINING SHORTS MADE WITH RECYCLED MAT...
# 146  A SLIM-FIT WORKOUT TEE MADE IN PART WITH RECYC...
#
#                                                 images  \
# 624  [https://assets.adidas.com/images/w_600,f_auto...
# 688  [https://assets.adidas.com/images/w_600,f_auto...
# 146  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                               name price original_price  \
# 624           PREMIUM ESSENTIALS HALF ZIP PULLOVER  $100           $100
# 688  AEROREADY DESIGNED TO MOVE WOVEN SPORT SHORTS   $24            $30
# 146    DESIGNED FOR TRAINING ADISTRONG WORKOUT TEE   $65            $65
#
#      review_count          scraped_at  \
# 624            13 2023-12-11 09:48:30
# 688          2462 2023-12-11 11:15:55
# 146             0 2023-12-11 05:10:34
#
#                                                    url  category cloth_gender
# 624  https://www.adidas.com/us/premium-essentials-h...  Clothing          Men
# 688  https://www.adidas.com/us/aeroready-designed-t...  Clothing          Men
# 146  https://www.adidas.com/us/designed-for-trainin...  Clothing          Men

# %%
# Thay thế các dấu /n trong description
descrip =  []
for index,item in enumerate(df.description):
    try:
        descrip.append(re.sub("\n"," ",item))
    except:
        descrip.append(item)

len(descrip)
# Out:
# 919

# %%
df.description = descrip
df.sample(2)
# Out:
#     availability  avg_rating   brand       color currency  \
# 93       InStock         4.8  adidas       Black      USA
# 646      InStock         4.8  adidas  Shadow Red      USA
#
#                                            description  \
# 93   A COMFORTABLE TEE WITH LONG SLEEVES AND FRESH ...
# 646                                               None
#
#                                                 images  \
# 93   [https://assets.adidas.com/images/w_600,f_auto...
# 646  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                             name price original_price  \
# 93   ADICOLOR CLASSICS 3-STRIPES LONG SLEEVE TEE   $45            $45
# 646                ADICOLOR CLASSICS WINDBREAKER   $60           $100
#
#      review_count          scraped_at  \
# 93            142 2023-12-11 03:49:21
# 646            58 2023-12-11 11:09:18
#
#                                                    url  category cloth_gender
# 93   https://www.adidas.com/us/adicolor-classics-3-...  Clothing          Men
# 646  https://www.adidas.com/us/adicolor-classics-wi...  Clothing          Men

# %%
price =  []
for index,item in enumerate(df.price):
    try:
        price.append(int(re.sub(r'\D', '', item)))
    except:
        price.append(item)

df.price = price
len(price)
# Out:
# 919

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand  color currency  \
# 537      InStock         NaN  adidas   None      USA
# 280      InStock         NaN  adidas  Black      USA
#
#                                            description  \
# 537  AN INSULATED Y-3 JACKET. Drawing on vintage ut...
# 280  A MOISTURE-ABSORBING TENNIS TEE MADE WITH NATU...
#
#                                                 images  \
# 537  [https://assets.adidas.com/images/w_600,f_auto...
# 280  [https://assets.adidas.com/images/w_600,f_auto...
#
#                              name  price original_price  review_count  \
# 537                          None    700           $700             0
# 280  TENNIS NEW YORK FREELIFT TEE     46            $65            29
#
#              scraped_at                                                url  \
# 537 2023-12-11 08:09:25  https://www.adidas.com/us/y-3-bomber-jacket/IP...
# 280 2023-12-11 06:05:29  https://www.adidas.com/us/tennis-new-york-free...
#
#      category cloth_gender
# 537  Clothing          Y-3
# 280  Clothing          Men

# %%
origin_price =  []
for index,item in enumerate(df.original_price):
    try:
        origin_price.append(int(re.sub(r'\D', '', item)))
    except:
        origin_price.append(item)

df.original_price = origin_price

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand    color currency  \
# 870      InStock         NaN  adidas    Black      USA
# 440      InStock         NaN  adidas  Savanna      USA
#
#                                            description  \
# 870  RUNNING SHORTS WITH INNER TIGHTS THAT FUSE STY...
# 440  AN ADIDAS HOODIE MEANT TO BE SPOTTED. From run...
#
#                                                 images  \
# 870  [https://assets.adidas.com/images/w_600,f_auto...
# 440  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                  name  price  original_price  review_count  \
# 870  DESIGNED 4 RUNNING 2-IN-1 SHORTS     55              55           146
# 440       GRAPHICS CAMO INFILL HOODIE     70              70            32
#
#              scraped_at                                                url  \
# 870 2023-12-11 12:30:29  https://www.adidas.com/us/designed-4-running-2...
# 440 2023-12-11 07:04:26  https://www.adidas.com/us/graphics-camo-infill...
#
#      category cloth_gender
# 870  Clothing          Men
# 440  Clothing          Men

# %%
df.dtypes
# Out:
# availability              object
# avg_rating               float64
# brand                     object
# color                     object
# currency                  object
# description               object
# images                    object
# name                      object
# price                      int64
# original_price             int64
# review_count               int64
# scraped_at        datetime64[ns]
# url                       object
# category                  object
# cloth_gender              object
# dtype: object

# %%
# Các cột cần chuyển về chữ thường
list_columns_convert_lower = ['availability', 'brand', 'color', 'currency','description','name','category','cloth_gender']
for col in list_columns_convert_lower:
    df[col] = df[col].str.lower()

# %%
df['avg_rating'].fillna(3, inplace=True)

# Xóa hàng nào có NaN trong cột 'name'
df.dropna(subset=['name'], inplace=True)

# Kiểm tra lại DataFrame sau khi đã chỉnh sửa
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# availability      0
# avg_rating        0
# brand             0
# color             0
# currency          0
# description       6
# images            0
# name              0
# price             0
# original_price    0
# review_count      0
# scraped_at        0
# url               0
# category          0
# cloth_gender      0
# dtype: int64

# %%
df['description'].fillna("", inplace=True)
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# availability      0
# avg_rating        0
# brand             0
# color             0
# currency          0
# description       0
# images            0
# name              0
# price             0
# original_price    0
# review_count      0
# scraped_at        0
# url               0
# category          0
# cloth_gender      0
# dtype: int64

# %%
df.to_csv('data_crawl.csv')

# %%
df.to_json("data.json")
