# %%
import pandas as pd
import numpy as np
import json 
import re

# %%
path = 'data_crawl_com_mock_prices.json'
df = pd.read_json(path)
df.sample(3)
# Out:
#    availability  avg_rating  brand            color currency  \
# 34      InStock         4.6  Hanes  [Nasa Meatball]     None
# 12     In Stock         4.5  YHOON         [Black ]  America
# 2      In Stock         4.4  Gilda          [White]  America
#
#                                           description  \
# 34  SHORT-SLEEVES - Sporty short-sleeve design kee...
# 12  Lightweight and Breathable:The stretchy,breath...
# 2   Fruit Of The Loom irregular short sleeve t-shi...
#
#                                                 image  \
# 34                                                NaN
# 12  https://i5.walmartimages.com/asr/0f7d2bf6-b1e5...
# 2   https://i5.walmartimages.com/seo/Fruit-Of-The-...
#
#                                                  name  price  original_price  \
# 34  Hanes Men’s Short Sleeve Graphic T-shirt Colle...   8.81           16.00
# 12  YHOON Women's Slip On Walking Shoes Lightweigh...  23.99           23.99
# 2   Gildan Adult Short Sleeve Crew T-Shirt for Cra...   3.48            7.61
#
#     review_count          scraped_at  \
# 34          80.0 2023-12-16 16:04:03
# 12           9.0 2023-12-16 09:57:25
# 2          660.0 2023-12-16 08:55:44
#
#                                                   url  category  \
# 34  https://www.amazon.com/Hanes-Mens-NASA-Meatbal...  T-shirts
# 12  https://www.walmart.com/ip/YHOON-Women-s-Slip-...     Shoes
# 2   https://www.walmart.com/ip/Gildan-Adult-Short-...  T-shirts
#
#                                           mock_prices  \
# 34  [5.529922795662461, 7.262900221454301, 13.1906...
# 12  [24.76398795477884, 19.993890165477396, 19.233...
# 2   [3.32529734819787, 3.067050953378966, 3.629907...
#
#                                                images
# 34  https://m.media-amazon.com/images/I/91SZR7U5OT...
# 12                                                NaN
# 2                                                 NaN

# %%
# Thay thế các dấu /n trong description
descrip =  []
for index,item in enumerate(df.description):
    try:
        descrip.append(re.sub("\n"," ",item))
    except:
        descrip.append(item)

len(descrip)
# Out:
# 47

# %%
df.description = descrip
df.sample(2)
# Out:
#    availability  avg_rating                brand                     color  \
# 14     In Stock         5.0      Disney Princess            [Purple, Blue]
# 35      InStock         4.6  Wrangler Authentics  [Black Denim, Stonewash]
#
#    currency                                        description  \
# 14  America  Your toddler girl is going to absolutely love ...
# 35     None  RELAXED FIT. Built with a relaxed fit through ...
#
#                                                 image  \
# 14  https://i5.walmartimages.com/seo/Disney-Prince...
# 35                                                NaN
#
#                                                  name  price  original_price  \
# 14  Disney Princess Toddler Girl Light Up Winter S...  14.99           34.99
# 35  Wrangler Authentics Men's Fleece Lined Five Po...  33.80           37.80
#
#     review_count          scraped_at  \
# 14           4.0 2023-12-16 10:01:47
# 35          64.0 2023-12-16 16:04:03
#
#                                                   url category  \
# 14  https://www.walmart.com/ip/Disney-Princess-Tod...    Shoes
# 35  https://www.amazon.com/Wrangler-Authentics-Fle...    Jeans
#
#                                           mock_prices  \
# 14  [12.892352164697844, 14.446608138348033, 16.08...
# 35  [41.52952486382727, 39.4395470296697, 29.96574...
#
#                                                images
# 14                                                NaN
# 35  https://m.media-amazon.com/images/I/81yVP2zUvI...

# %%
price =  []
for index,item in enumerate(df.price):
    try:
        price.append(int(re.sub(r'\D', '', item)))
    except:
        price.append(item)

df.price = price
len(price)
# Out:
# 47

# %%
df.sample(2)
# Out:
#    availability  avg_rating         brand  \
# 22     In Stock         4.5  Calvin Klein
# 42      InStock         4.0         Prada
#
#                                             color currency  \
# 22  [Forever Black, Boston Blue Black, Limelight]  America
# 42                                        [White]    Italy
#
#                                           description  \
# 22  An iconic essential, our reimagined jeans are ...
# 42  This Prada Women's White Vitello Phenix Leathe...
#
#                                                 image  \
# 22  https://calvinklein.scene7.com/is/image/Calvin...
# 42                                                NaN
#
#                                                  name   price  original_price  \
# 22                             Standard Straight Jean    53.7            89.5
# 42  Prada Women's White Vitello Phenix Leather Cro...  2950.0          2950.0
#
#     review_count          scraped_at  \
# 22          28.0 2023-12-16 13:10:02
# 42           0.0 2023-12-16 16:04:13
#
#                                                   url  category  \
# 22  https://www.calvinklein.us/en/men/apparel/bott...     Jeans
# 42  https://www.amazon.com/Prada-Vitello-Leather-C...  Handbags
#
#                                           mock_prices  \
# 22  [55.51529577376878, 55.519158404005836, 49.995...
# 42  [2479.424049183421, 2702.9115114927104, 2671.8...
#
#                                                images
# 22                                                NaN
# 42  https://m.media-amazon.com/images/I/61+bWxNQc-...

# %%
origin_price =  []
for index,item in enumerate(df.original_price):
    try:
        origin_price.append(int(re.sub(r'\D', '', item)))
    except:
        origin_price.append(item)

df.original_price = origin_price

# %%
df.sample(2)
# Out:
#    availability  avg_rating         brand           color currency  \
# 26     In Stock         4.0  Calvin Klein  [Black , Tofu]  America
# 42      InStock         4.0         Prada         [White]    Italy
#
#                                           description  \
# 26  Designed with curved shaping, this shoulder ba...
# 42  This Prada Women's White Vitello Phenix Leathe...
#
#                                                 image  \
# 26  https://calvinklein.scene7.com/is/image/Calvin...
# 42                                                NaN
#
#                                                  name   price  original_price  \
# 26               Archive Hardware Buckle Shoulder Bag    93.7           139.5
# 42  Prada Women's White Vitello Phenix Leather Cro...  2950.0          2950.0
#
#     review_count          scraped_at  \
# 26           8.0 2023-12-16 13:19:44
# 42           0.0 2023-12-16 16:04:13
#
#                                                   url  category  \
# 26  https://www.calvinklein.us/en/women/accessorie...  Handbags
# 42  https://www.amazon.com/Prada-Vitello-Leather-C...  Handbags
#
#                                           mock_prices  \
# 26  [84.68768087245024, 94.75174778906195, 102.769...
# 42  [2479.424049183421, 2702.9115114927104, 2671.8...
#
#                                                images
# 26                                                NaN
# 42  https://m.media-amazon.com/images/I/61+bWxNQc-...

# %%
df.dtypes
# Out:
# availability              object
# avg_rating               float64
# brand                     object
# color                     object
# currency                  object
# description               object
# image                     object
# name                      object
# price                    float64
# original_price           float64
# review_count             float64
# scraped_at        datetime64[ns]
# url                       object
# category                  object
# mock_prices               object
# images                    object
# dtype: object

# %%
# Các cột cần chuyển về chữ thường
list_columns_convert_lower = ['availability', 'brand', 'color', 'currency','description','name','category','cloth_gender']
for col in list_columns_convert_lower:
    df[col] = df[col].str.lower()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cloth_gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#       2 list_columns_convert_lower = ['availability', 'brand', 'color', 'currency','description','name','category','cloth_gender']
#       3 for col in list_columns_convert_lower:
# ----> 4     df[col] = df[col].str.lower()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'cloth_gender'

# %%
df['avg_rating'].fillna(3, inplace=True)

# Xóa hàng nào có NaN trong cột 'name'
df.dropna(subset=['name'], inplace=True)

# Kiểm tra lại DataFrame sau khi đã chỉnh sửa
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# availability      0
# avg_rating        0
# brand             0
# color             0
# currency          0
# description       6
# images            0
# name              0
# price             0
# original_price    0
# review_count      0
# scraped_at        0
# url               0
# category          0
# cloth_gender      0
# dtype: int64

# %%
df['description'].fillna("", inplace=True)
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# availability       0
# avg_rating         2
# brand              0
# color             46
# currency           6
# description        0
# image             17
# name               0
# price              0
# original_price     0
# review_count       0
# scraped_at         2
# url                0
# category           0
# mock_prices        0
# images            30
# dtype: int64

# %%
df.to_json("data.json")
