# %%
import pandas as pd
import numpy as np
import json 
import re

# %%
path = 'data_adidas_2.json'
df = pd.read_json(path)
df.sample(3)
# Out:
#     availability  avg_rating   brand             color currency  \
# 597      InStock         NaN  adidas      Night Indigo      USA
# 730      InStock         NaN  adidas             Black      USA
# 286   OutOfStock         NaN  adidas  Olive Strata S23      USA
#
#                                            description  \
# 597  THIS LOOSE-FIT WINDBREAKER IS MADE IN PART WIT...
# 730  EVERYDAY SHORTS MADE WITH A BLEND OF RECYCLED ...
# 286  AN EVERYDAY HOODIE MADE WITH A BLEND OF RECYCL...
#
#                                                 images  \
# 597  [https://assets.adidas.com/images/w_600,f_auto...
# 730  [https://assets.adidas.com/images/w_600,f_auto...
# 286  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                             name price original_price  \
# 597                 ADICOLOR TREFOIL WINDBREAKER  $100           $100
# 730                        Z.N.E. PREMIUM SHORTS   $65            $65
# 286  ESSENTIALS FLEECE 3-STRIPES FULL-ZIP HOODIE   $30            $65
#
#      review_count          scraped_at  \
# 597             0 2023-12-11 09:15:25
# 730            61 2023-12-11 11:36:23
# 286             0 2023-12-11 06:07:21
#
#                                                    url  category cloth_gender
# 597  https://www.adidas.com/us/adicolor-trefoil-win...  Clothing          Men
# 730  https://www.adidas.com/us/z.n.e.-premium-short...  Clothing          Men
# 286  https://www.adidas.com/us/essentials-fleece-3-...  Clothing          Men

# %%
# Thay thế các dấu /n trong description
descrip =  []
for index,item in enumerate(df.description):
    try:
        descrip.append(re.sub("\n"," ",item))
    except:
        descrip.append(item)

len(descrip)
# Out:
# 919

# %%
df.description = descrip
df.sample(2)
# Out:
#     availability  avg_rating   brand        color currency  \
# 629      InStock         4.5  adidas  Pulse Olive      USA
# 238      InStock         NaN  adidas         None      USA
#
#                                            description  \
# 629  WATERPROOF SKI PANTS MADE IN PART WITH RECYCLE...
# 238  A Y-3 TEE THAT PLAYS WITH THE CLASSIC 3-STRIPE...
#
#                                                 images  \
# 629  [https://assets.adidas.com/images/w_600,f_auto...
# 238  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                               name price original_price  \
# 629  TERREX 3-LAYER POST-CONSUMER NYLON SNOW PANTS  $400           $400
# 238                                           None  $200           $200
#
#      review_count          scraped_at  \
# 629             4 2023-12-11 09:51:11
# 238             2 2023-12-11 05:54:35
#
#                                                    url  category cloth_gender
# 629  https://www.adidas.com/us/terrex-3-layer-post-...  Clothing          Men
# 238  https://www.adidas.com/us/y-3-3-stripes-short-...  Clothing          Y-3

# %%
price =  []
for index,item in enumerate(df.price):
    try:
        price.append(int(re.sub(r'\D', '', item)))
    except:
        price.append(item)

df.price = price
len(price)
# Out:
# 919

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand          color currency  \
# 421   OutOfStock         NaN  adidas  Arctic Fusion      USA
# 769      InStock         NaN  adidas  Black / White      USA
#
#                                            description  \
# 421  A COZY HOODIE MADE WITH A BLEND OF RECYCLED AN...
# 769  VERSATILE TRAINING SHORTS MADE WITH RECYCLED M...
#
#                                                 images  \
# 421  [https://assets.adidas.com/images/w_600,f_auto...
# 769  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                       name  price original_price  \
# 421            ALL SZN GARMENT-WASH HOODIE     30            $65
# 769  TRAIN ESSENTIALS LOGO TRAINING SHORTS     14            $35
#
#      review_count          scraped_at  \
# 421             0 2023-12-11 06:56:45
# 769            61 2023-12-11 12:01:22
#
#                                                    url  category cloth_gender
# 421  https://www.adidas.com/us/all-szn-garment-wash...  Clothing          Men
# 769  https://www.adidas.com/us/train-essentials-log...  Clothing          Men

# %%
origin_price =  []
for index,item in enumerate(df.original_price):
    try:
        origin_price.append(int(re.sub(r'\D', '', item)))
    except:
        origin_price.append(item)

df.original_price = origin_price

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand                      color currency  \
# 234      InStock         3.9  adidas  Silver Pebble S23 / White      USA
# 733      InStock         NaN  adidas                      Black      USA
#
#                                            description  \
# 234  A MOISTURE-ABSORBING T-SHIRT, MADE IN PART WIT...
# 733  COMFORTABLE SHORTS WITH ANIMAL STRIPES. Style ...
#
#                                                 images  \
# 234  [https://assets.adidas.com/images/w_600,f_auto...
# 733  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                                 name  price  original_price  \
# 234  TRAIN ICONS SMALL LOGO LONG SLEEVE TRAINING TEE     35              50
# 733                           GRAPHICS ANIMAL SHORTS     65              65
#
#      review_count          scraped_at  \
# 234            16 2023-12-11 05:53:11
# 733             0 2023-12-11 11:36:48
#
#                                                    url  category cloth_gender
# 234  https://www.adidas.com/us/train-icons-small-lo...  Clothing          Men
# 733  https://www.adidas.com/us/graphics-animal-shor...  Clothing          Men

# %%
df.dtypes
# Out:
# availability              object
# avg_rating               float64
# brand                     object
# color                     object
# currency                  object
# description               object
# images                    object
# name                      object
# price                      int64
# original_price             int64
# review_count               int64
# scraped_at        datetime64[ns]
# url                       object
# category                  object
# cloth_gender              object
# dtype: object

# %%
df.to_csv('data_crawl.csv')
