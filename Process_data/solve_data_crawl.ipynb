# %%
import pandas as pd
import numpy as np
import json 
import re

# %%
path = 'data_adidas_2.json'
df = pd.read_json(path)
df.sample(3)
# Out:
#     availability  avg_rating   brand  \
# 630      InStock         NaN  adidas
# 829      InStock         4.3  adidas
# 198      InStock         NaN  adidas
#
#                                         color currency  \
# 630                               Sand Strata      USA
# 829                                     White      USA
# 198  Team Navy / Team Colleg Burgundy / Multi      USA
#
#                                            description  \
# 630  A WIND-RESISTANT HOODIE MADE WITH RECYCLED MAT...
# 829  SHORTS THAT SUIT EVERY GAME, MADE IN PART WITH...
# 198  A HOCKEY-STYLE T-SHIRT FOR AVALANCHE FANS.\nBe...
#
#                                                 images  \
# 630  [https://assets.adidas.com/images/w_600,f_auto...
# 829  [https://assets.adidas.com/images/w_600,f_auto...
# 198  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                     name price original_price  review_count  \
# 630  MYSHELTER WINDWEAVE HOODED PULLOVER  $112           $160             7
# 829     CLUB TENNIS STRETCH WOVEN SHORTS   $35            $50            14
# 198                 AVALANCHE HOCKEY TEE   $49            $70             3
#
#              scraped_at                                                url  \
# 630 2023-12-11 09:51:58  https://www.adidas.com/us/myshelter-windweave-...
# 829 2023-12-11 12:17:40  https://www.adidas.com/us/club-tennis-stretch-...
# 198 2023-12-11 05:44:13  https://www.adidas.com/us/avalanche-hockey-tee...
#
#      category cloth_gender
# 630  Clothing          Men
# 829  Clothing          Men
# 198  Clothing          Men

# %%
# Thay thế các dấu /n trong description
descrip =  []
for index,item in enumerate(df.description):
    try:
        descrip.append(re.sub("\n"," ",item))
    except:
        descrip.append(item)

len(descrip)
# Out:
# 919

# %%
df.description = descrip
df.sample(2)
# Out:
#     availability  avg_rating   brand                 color currency  \
# 122      InStock         4.7  adidas  Semi Pulse Lilac F22      USA
# 812      InStock         NaN  adidas         White / Black      USA
#
#                                            description  \
# 122  A MOISTURE-ABSORBING TENNIS TEE MADE WITH NATU...
# 812  VERSATILE WORKOUT SHORTS MADE WITH RECYCLED MA...
#
#                                                 images  \
# 122  [https://assets.adidas.com/images/w_600,f_auto...
# 812  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                                  name price original_price  \
# 122                      TENNIS NEW YORK FREELIFT TEE   $26            $65
# 812  TRAIN ESSENTIALS PIQUÉ 3-STRIPES TRAINING SHORTS   $28            $35
#
#      review_count          scraped_at  \
# 122            29 2023-12-11 05:06:57
# 812           216 2023-12-11 12:12:02
#
#                                                    url  category cloth_gender
# 122  https://www.adidas.com/us/tennis-new-york-free...  Clothing          Men
# 812  https://www.adidas.com/us/train-essentials-piq...  Clothing          Men

# %%
price =  []
for index,item in enumerate(df.price):
    try:
        price.append(int(re.sub(r'\D', '', item)))
    except:
        price.append(item)

df.price = price
len(price)
# Out:
# 919

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand            color currency  \
# 524      InStock         4.7  adidas            White      USA
# 329      InStock         NaN  adidas  Collegiate Navy      USA
#
#                                            description  \
# 524  A SLIM-FITTING LAYER FOR TRAINING, MADE WITH R...
# 329  A GOLF PULLOVER WITH A KANGAROO POCKET. All th...
#
#                                                 images  \
# 524  [https://assets.adidas.com/images/w_600,f_auto...
# 329  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                name  price original_price  review_count  \
# 524  TIRO 23 LEAGUE TRAINING JACKET     44            $55           256
# 329          GO-TO 1/2-ZIP PULLOVER    110           $110            15
#
#              scraped_at                                                url  \
# 524 2023-12-11 07:51:22  https://www.adidas.com/us/tiro-23-league-train...
# 329 2023-12-11 06:24:10  https://www.adidas.com/us/go-to-1-2-zip-pullov...
#
#      category cloth_gender
# 524  Clothing          Men
# 329  Clothing          Men

# %%
origin_price =  []
for index,item in enumerate(df.original_price):
    try:
        origin_price.append(int(re.sub(r'\D', '', item)))
    except:
        origin_price.append(item)

df.original_price = origin_price

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand       color currency  \
# 807      InStock         NaN  adidas       Black      USA
# 469      InStock         NaN  adidas  Legend Ink      USA
#
#                                            description  \
# 807  MOISTURE-WICKING SUPPORTER SHORTS FOR MAN UTD,...
# 469  A LAID-BACK SWEATSHIRT MADE IN COLLABORATION W...
#
#                                                 images  \
# 807  [https://assets.adidas.com/images/w_600,f_auto...
# 469  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                             name  price  original_price  \
# 807          MANCHESTER UNITED 23/24 AWAY SHORTS     60              60
# 469  ADIDAS X PARLEY SWEATSHIRT (GENDER NEUTRAL)     48             120
#
#      review_count          scraped_at  \
# 807             2 2023-12-11 12:10:50
# 469            26 2023-12-11 07:15:46
#
#                                                    url  category cloth_gender
# 807  https://www.adidas.com/us/manchester-united-23...  Clothing          Men
# 469  https://www.adidas.com/us/adidas-x-parley-swea...  Clothing     Training

# %%
df.dtypes
# Out:
# availability              object
# avg_rating               float64
# brand                     object
# color                     object
# currency                  object
# description               object
# images                    object
# name                      object
# price                      int64
# original_price             int64
# review_count               int64
# scraped_at        datetime64[ns]
# url                       object
# category                  object
# cloth_gender              object
# dtype: object

# %%
# Các cột cần chuyển về chữ thường
list_columns_convert_lower = ['availability', 'brand', 'color', 'currency','description','name','category','cloth_gender']
for col in list_columns_convert_lower:
    df[col] = df[col].str.lower()

# %%
df.to_csv('data_crawl.csv')
