# %%
import pandas as pd
import numpy as np
import json 
import re

# %%
path = 'data_adidas_2.json'
df = pd.read_json(path)
df.sample(3)
# Out:
#     availability  avg_rating   brand                                    color  \
# 71       InStock         NaN  adidas                      White / Mls-Mif-37t
# 443      InStock         5.0  adidas  Team Power Red / Mgh Solid Grey / Multi
# 52       InStock         NaN  adidas                      Red / Black / Multi
#
#     currency                                        description  \
# 71       USA  A SOCCER TEE CELEBRATING MESSI'S ARRIVAL IN MI...
# 443      USA  A RED WINGS HOODIE WITH ZIP POCKETS, MADE WITH...
# 52       USA  A HOCKEY-STYLE T-SHIRT FOR BLACKHAWKS FANS.\nB...
#
#                                                 images  \
# 71   [https://assets.adidas.com/images/w_600,f_auto...
# 443  [https://assets.adidas.com/images/w_600,f_auto...
# 52   [https://assets.adidas.com/images/w_600,f_auto...
#
#                                      name price original_price  review_count  \
# 71                              MESSI TEE   $28            $35            13
# 443  RED WINGS TEAM ISSUE PULLOVER HOODIE   $70            $70             4
# 52                  BLACKHAWKS HOCKEY TEE   $49            $70             3
#
#              scraped_at                                                url  \
# 71  2023-12-11 03:49:21    https://www.adidas.com/us/messi-tee/JH1135.html
# 443 2023-12-11 07:05:14  https://www.adidas.com/us/red-wings-team-issue...
# 52  2023-12-11 03:49:21  https://www.adidas.com/us/blackhawks-hockey-te...
#
#      category cloth_gender
# 71   Clothing          Men
# 443  Clothing          Men
# 52   Clothing          Men

# %%
# Thay thế các dấu /n trong description
descrip =  []
for index,item in enumerate(df.description):
    try:
        descrip.append(re.sub("\n"," ",item))
    except:
        descrip.append(item)

len(descrip)
# Out:
# 919

# %%
df.description = descrip
df.sample(2)
# Out:
#     availability  avg_rating   brand                  color currency  \
# 733      InStock         NaN  adidas                  Black      USA
# 500      InStock         4.7  adidas  Black / White / White      USA
#
#                                            description  \
# 733  COMFORTABLE SHORTS WITH ANIMAL STRIPES. Style ...
# 500  A TRACK JACKET MADE IN PART WITH A BLEND OF RE...
#
#                                                 images  \
# 733  [https://assets.adidas.com/images/w_600,f_auto...
# 500  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                    name price original_price  review_count  \
# 733              GRAPHICS ANIMAL SHORTS   $65            $65             0
# 500  ADICOLOR CLASSICS SST TRACK JACKET   $80            $80           171
#
#              scraped_at                                                url  \
# 733 2023-12-11 11:36:48  https://www.adidas.com/us/graphics-animal-shor...
# 500 2023-12-11 07:36:41  https://www.adidas.com/us/adicolor-classics-ss...
#
#      category cloth_gender
# 733  Clothing          Men
# 500  Clothing          Men

# %%
price =  []
for index,item in enumerate(df.price):
    try:
        price.append(int(re.sub(r'\D', '', item)))
    except:
        price.append(item)

df.price = price
len(price)
# Out:
# 919

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand             color currency  \
# 895      InStock         NaN  adidas  Wonder Beige F23      USA
# 420   OutOfStock         NaN  adidas   Wonder Clay F23      USA
#
#                                            description  \
# 895  SUPER-SOFT SHORTS WITH SUBTLE MICRO TREFOIL DE...
# 420  A SOFT AND WARM SWEATSHIRT WITH A SPECIAL REMI...
#
#                                                 images  \
# 895  [https://assets.adidas.com/images/w_600,f_auto...
# 420  [https://assets.adidas.com/images/w_600,f_auto...
#
#                           name  price original_price  review_count  \
# 895  PREMIUM ESSENTIALS SHORTS     55            $55            27
# 420   LOUNGE FLEECE SWEATSHIRT     26            $65             0
#
#              scraped_at                                                url  \
# 895 2023-12-11 12:48:38  https://www.adidas.com/us/premium-essentials-s...
# 420 2023-12-11 06:56:34  https://www.adidas.com/us/lounge-fleece-sweats...
#
#      category cloth_gender
# 895  Clothing          Men
# 420  Clothing          Men

# %%
origin_price =  []
for index,item in enumerate(df.original_price):
    try:
        origin_price.append(int(re.sub(r'\D', '', item)))
    except:
        origin_price.append(item)

df.original_price = origin_price

# %%
df.sample(2)
# Out:
#     availability  avg_rating   brand  color currency  \
# 547      InStock         NaN  adidas  Black      USA
# 718      InStock         NaN  adidas  Black      USA
#
#                                            description  \
# 547  A BOMBER JACKET FOR COMFORT ON THE GO, MADE WI...
# 718  STAY COOL IN TENNIS SHORTS MADE IN PART WITH R...
#
#                                                 images  \
# 547  [https://assets.adidas.com/images/w_600,f_auto...
# 718  [https://assets.adidas.com/images/w_600,f_auto...
#
#                                       name  price  original_price  \
# 547  BEST OF ADIDAS TRAINING BOMBER JACKET     76             190
# 718                     TENNIS ERGO SHORTS     60              60
#
#      review_count          scraped_at  \
# 547            16 2023-12-11 08:14:06
# 718             0 2023-12-11 11:34:12
#
#                                                    url  category cloth_gender
# 547  https://www.adidas.com/us/best-of-adidas-train...  Clothing          Men
# 718  https://www.adidas.com/us/tennis-ergo-shorts/I...  Clothing          Men

# %%
df.dtypes
# Out:
# availability              object
# avg_rating               float64
# brand                     object
# color                     object
# currency                  object
# description               object
# images                    object
# name                      object
# price                      int64
# original_price             int64
# review_count               int64
# scraped_at        datetime64[ns]
# url                       object
# category                  object
# cloth_gender              object
# dtype: object

# %%
# Các cột cần chuyển về chữ thường
list_columns_convert_lower = ['availability', 'brand', 'color', 'currency','description','name','category','cloth_gender']
for col in list_columns_convert_lower:
    df[col] = df[col].str.lower()

# %%
df['avg_rating'].fillna(3, inplace=True)

# Xóa hàng nào có NaN trong cột 'name'
df.dropna(subset=['name'], inplace=True)

# Kiểm tra lại DataFrame sau khi đã chỉnh sửa
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# availability      0
# avg_rating        0
# brand             0
# color             0
# currency          0
# description       6
# images            0
# name              0
# price             0
# original_price    0
# review_count      0
# scraped_at        0
# url               0
# category          0
# cloth_gender      0
# dtype: int64

# %%
df['description'].fillna("", inplace=True)
nan_counts = df.isna().sum()

print(nan_counts)
# Out:
# availability      0
# avg_rating        0
# brand             0
# color             0
# currency          0
# description       0
# images            0
# name              0
# price             0
# original_price    0
# review_count      0
# scraped_at        0
# url               0
# category          0
# cloth_gender      0
# dtype: int64

# %%
df.to_csv('data_crawl.csv')
