# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("adidas_nikes_products_mentor_data.xlsx")
df.head()
# Out:
#    Unnamed: 0 availability  avg_rating   brand                   color  \
# 0         485      InStock         4.1  adidas                   Black
# 1         650      InStock         4.4  adidas                  Purple
# 2          72      InStock         NaN    Nike   Rush Blue/White/White
# 3         447      InStock         4.5  adidas                   Black
# 4          44      InStock         NaN    Nike  Black/Black/Light Bone
#
#   currency                                        description  \
# 0      USD  Can you ever really lose spirit? The adidas ZX...
# 1      USD  Follow your breath to a place where your mind ...
# 2      USD   Rep your team in the Philadelphia 76ers Short...
# 3      USD  Some players talk a good game. But the best on...
# 4      USD  BIG AIR + COZY COMFORT.Grab the hoodie that fe...
#
#                                               images  \
# 0  https://assets.adidas.com/images/w_600,f_auto,...
# 1  https://assets.adidas.com/images/w_600,f_auto,...
# ...

# %%
# Xóa cột "Unnamed: 0" nếu nó tồn tại
if 'Unnamed: 0' in df.columns:
    df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#     availability  avg_rating   brand                    color currency  \
# 0        InStock         4.1  adidas                    Black      USD
# 1        InStock         4.4  adidas                   Purple      USD
# 2        InStock         NaN    Nike    Rush Blue/White/White      USD
# 3        InStock         4.5  adidas                    Black      USD
# 4        InStock         NaN    Nike   Black/Black/Light Bone      USD
# ..           ...         ...     ...                      ...      ...
# 282      InStock         4.5  adidas                     Grey      USD
# 283   OutOfStock         NaN    Nike  Grey Heather/Valor Blue      USD
# 284      InStock         4.6  adidas                 Burgundy      USD
# 285      InStock         4.7  adidas                    White      USD
# 286      InStock         4.8  adidas               Multicolor      USD
#
#                                            description  \
# 0    Can you ever really lose spirit? The adidas ZX...
# ...

# %%
df["images"][0].split("~")
# Out:
# ['https://assets.adidas.com/images/w_600,f_auto,q_auto/027ab9d8671a4ccd9087ac0900cbd5e8_9366/ZX_700_HD_Shoes_Black_G55780_01_standard.jpg',
#  'https://assets.adidas.com/images/w_600,f_auto,q_auto/7a734476ac854919bedfac0900cc00d7_9366/ZX_700_HD_Shoes_Black_G55780_012_hover_standard.jpg',
#  'https://assets.adidas.com/images/w_600,f_auto,q_auto/be147f0919be42acad60ac0900cbe39f_9366/ZX_700_HD_Shoes_Black_G55780_02_standard.jpg',
#  'https://assets.adidas.com/images/w_600,f_auto,q_auto/e480339f42c549ed9274ac0900cbea45_9366/ZX_700_HD_Shoes_Black_G55780_03_standard.jpg',
#  'https://assets.adidas.com/images/w_600,f_auto,q_auto/518d083c1c574a59ac62ac0900cbf1c2_9366/ZX_700_HD_Shoes_Black_G55780_04_standard.jpg',
#  'https://assets.adidas.com/images/w_600,f_auto,q_auto/3f6d7753862e471689c7ac0900cbf936_9366/ZX_700_HD_Shoes_Black_G55780_05_standard.jpg',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  286 non-null    object
#  1   avg_rating    257 non-null    float64
#  2   brand         287 non-null    object
#  3   color         287 non-null    object
#  4   currency      287 non-null    object
#  5   description   287 non-null    object
#  6   images        286 non-null    object
#  7   name          287 non-null    object
#  8   price         287 non-null    float64
#  9   review_count  257 non-null    float64
#  10  scraped_at    287 non-null    object
#  11  url           287 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 27.0+ KB

# %%
# Thêm cột "sale" với giá trị 0
df['sale'] = 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   availability  286 non-null    object
#  1   avg_rating    257 non-null    float64
#  2   brand         287 non-null    object
#  3   color         287 non-null    object
#  4   currency      287 non-null    object
#  5   description   287 non-null    object
#  6   images        286 non-null    object
#  7   name          287 non-null    object
#  8   price         287 non-null    float64
#  9   review_count  257 non-null    float64
#  10  scraped_at    287 non-null    object
#  11  url           287 non-null    object
#  12  sale          287 non-null    int64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 29.3+ KB

# %%
df.head(3)
# Out:
#   availability  avg_rating   brand                  color currency  \
# 0      InStock         4.1  adidas                  Black      USD
# 1      InStock         4.4  adidas                 Purple      USD
# 2      InStock         NaN    Nike  Rush Blue/White/White      USD
#
#                                          description  \
# 0  Can you ever really lose spirit? The adidas ZX...
# 1  Follow your breath to a place where your mind ...
# 2   Rep your team in the Philadelphia 76ers Short...
#
#                                               images  \
# 0  https://assets.adidas.com/images/w_600,f_auto,...
# 1  https://assets.adidas.com/images/w_600,f_auto,...
# 2  https://static.nike.com/a/images/t_PDP_1280_v1...
#
#                            name  price  review_count  \
# 0               ZX 700 HD Shoes   63.0         251.0
# 1  Elevate Yoga Flow 7/8 Tights   72.0          44.0
# 2            Philadelphia 76ers   48.0           NaN
#
#                    scraped_at  \
# ...

# %%
# Các cột cần chuyển về chữ thường
list_columns_convert_lower = ['availability', 'brand', 'color', 'currency']
for col in list_columns_convert_lower:
    df[col] = df[col].str.lower()

# %%
df.head(3)
# Out:
#   availability  avg_rating   brand                  color currency  \
# 0      instock         4.1  adidas                  black      usd
# 1      instock         4.4  adidas                 purple      usd
# 2      instock         NaN    nike  rush blue/white/white      usd
#
#                                          description  \
# 0  Can you ever really lose spirit? The adidas ZX...
# 1  Follow your breath to a place where your mind ...
# 2   Rep your team in the Philadelphia 76ers Short...
#
#                                               images  \
# 0  https://assets.adidas.com/images/w_600,f_auto,...
# 1  https://assets.adidas.com/images/w_600,f_auto,...
# 2  https://static.nike.com/a/images/t_PDP_1280_v1...
#
#                            name  price  review_count  \
# 0               ZX 700 HD Shoes   63.0         251.0
# 1  Elevate Yoga Flow 7/8 Tights   72.0          44.0
# 2            Philadelphia 76ers   48.0           NaN
#
#                    scraped_at  \
# ...

# %%
df.to_csv("data_btc.csv")
